# %% [markdown]
# <a href="https://colab.research.google.com/github/Bassantv/AI111course/blob/main/Crop_production_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.2/356.2 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 58.0 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=f7fba36b45dd7f2638ef897e397697007526cb9ae4bf61b2543794c8fbc4889c
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
#prepration before analysis
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model
from ydata_profiling import ProfileReport
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
crop_production=pd.read_csv('/content/crop_production.csv')

crop_production.tail()
# Out:
#               State District    Crop  Crop_Year       Season   Area   \
# 345331  West Bengal   PURULIA  Wheat       2015  Rabi          855.0
# 345332  West Bengal   PURULIA  Wheat       2016  Rabi         1366.0
# 345333  West Bengal   PURULIA  Wheat       2017  Rabi         1052.0
# 345334  West Bengal   PURULIA  Wheat       2018  Rabi          833.0
# 345335  West Bengal   PURULIA  Wheat       2019  Rabi          516.0
#
#         Production  Yield
# 345331      1241.0   1.45
# 345332      2415.0   1.77
# 345333      2145.0   2.04
# 345334      2114.0   2.54
# 345335       931.0   1.80

# %%
crop_production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345336 entries, 0 to 345335
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   State       345336 non-null  object
#  1   District    345336 non-null  object
#  2   Crop        345327 non-null  object
#  3   Crop_Year   345336 non-null  int64
#  4   Season      345336 non-null  object
#  5   Area        345336 non-null  float64
#  6   Production  340388 non-null  float64
#  7   Yield       345336 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 21.1+ MB

# %%
crop_production.describe()
# Out:
#            Crop_Year         Area     Production          Yield
# count  345336.000000  3.453360e+05  3.403880e+05  345336.000000
# mean     2008.887512  1.167147e+04  9.584726e+05      79.423135
# std         6.564361  4.584079e+04  2.153068e+07     916.678396
# min      1997.000000  4.000000e-03  0.000000e+00       0.000000
# 25%      2003.000000  7.400000e+01  8.700000e+01       0.550000
# 50%      2009.000000  5.320000e+02  7.170000e+02       1.000000
# 75%      2015.000000  4.112000e+03  7.182000e+03       2.470000
# max      2020.000000  8.580100e+06  1.597800e+09   43958.330000

# %%
crop_production.isnull().sum()
# Out:
# State            0
# District         0
# Crop             9
# Crop_Year        0
# Season           0
# Area             0
# Production    4948
# Yield            0
# dtype: int64

# %%
crop_production.dtypes
# Out:
# State          object
# District       object
# Crop           object
# Crop_Year       int64
# Season         object
# Area          float64
# Production    float64
# Yield         float64
# dtype: object

# %%
crop_production.dropna(inplace=True)
crop_production.isnull().sum()
# Out:
# State         0
# District      0
# Crop          0
# Crop_Year     0
# Season        0
# Area          0
# Production    0
# Yield         0
# dtype: int64

# %%
crop_production.duplicated().sum()
# Out:
# 0

# %%
profile=ProfileReport(crop_production)
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.10.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-10-06 18:52:12.945578&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
print(crop_production.columns)
# Out:
# Index(['State', 'District ', 'Crop', 'Crop_Year', 'Season', 'Area ',
#        'Production', 'Yield'],
#       dtype='object')

# %%
x=crop_production.drop(['Production','Season','State', 'District ', 'Crop', 'Crop_Year'], axis='columns')

y = crop_production['Production']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
y_train.isnull().any()
# Out:
# False

# %%
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_train,y_train)
# Out:
# 0.1852572877488632

# %%
from sklearn.metrics import r2_score
ypred=reg.predict(x_test)
r2_score(y_test,ypred)
# Out:
# 0.23061850745114654

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(x_train)
X_test=scaler.transform(x_test)

# %%
reg.score(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -0.002152816295254878

# %%
ypred=reg.predict(X_test)
r2_score(y_test,ypred)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# -0.0017095968751814627
